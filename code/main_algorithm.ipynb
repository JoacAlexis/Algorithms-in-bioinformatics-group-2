# %% [markdown]
# ## Imports

# %%
# import packages

# %% [markdown]
# ## Prepare data

# %%
#load protein sequences 

seq_length = 30

#cut all sequences to length 30

#make joined dataset with 30-mer peptides and their translocation (mitochondiral = 1, cytosol = 0)
